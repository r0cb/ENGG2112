# %% [markdown]
# # KNN Model Notebook
# This notebook was converted from .
# Run the cells in order to load data, train the model, and evaluate results.

# %%
ax.set_xlabel('Recall'); ax.set_ylabel('Precision')
ax.set_title('Precision-recall curve'); ax.legend()

plt.tight_layout(); plt.show()
# Out:
# Stacked dataset: (357, 39)
# Demographic features (5): ['pct_foreign_born', 'avg_household_size', 'pop_density_per_sqmi', 'public_transport_pct', 'pct_elderly']
# Disease dummies: ['disease_FLU', 'disease_RSV']
# State dummies: ['state_DE', 'state_NY', 'state_PA']
# X shape: (357, 10)
# Outbreak rate: 26.1%
# Unique counties: 149
# Best params: n_neighbors=21, weights=distance, metric=manhattan
# Best CV PR-AUC: 0.538
#
# Final model fit on all 357 observations
# Cross-validated metrics (out-of-fold, group-split CV):
#
#   accuracy    : 0.770
#   precision   : 0.667
#   recall      : 0.237
#   f1          : 0.349
#   roc_auc     : 0.659
#   pr_auc      : 0.470 ← HEADLINE
#   brier       : 0.176
#
# Baselines:
#   Always-zero accuracy: 0.739
#   Random PR-AUC:        0.261
#
# === Classification report ===
#               precision    recall  f1-score   support
#
# Non-outbreak       0.78      0.96      0.86       264
#     Outbreak       0.67      0.24      0.35        93
#
#     accuracy                           0.77       357
#    macro avg       0.72      0.60      0.60       357
# weighted avg       0.75      0.77      0.73       357
# Permutation importance (100 repeats, scoring=average_precision):
#
#              feature  importance_mean  importance_std  ci_lower  ci_upper  stable
#     pct_foreign_born            0.226           0.020     0.186     0.259    True
#   avg_household_size            0.334           0.032     0.282     0.395    True
# pop_density_per_sqmi            0.012           0.004     0.007     0.021    True
# public_transport_pct            0.037           0.008     0.025     0.054    True
#          pct_elderly            0.313           0.025     0.271     0.356    True
#          disease_FLU            0.294           0.033     0.223     0.352    True
#          disease_RSV            0.181           0.021     0.145     0.223    True
#             state_DE            0.000           0.000     0.000     0.001   False
#             state_NY            0.067           0.013     0.043     0.094    True
#             state_PA            0.080           0.015     0.051     0.111    True
#
# Stable features (CI does not cross zero): 9/10
# Performance by disease:
#
#              n  positives  pr_auc  roc_auc  accuracy
# disease
# COVID    140.0       36.0   0.593    0.724     0.807
# FLU      141.0       37.0   0.435    0.626     0.766
# RSV       76.0       20.0   0.328    0.544     0.711
#
# Performance by state:
#
#            n  positives  pr_auc  accuracy
# state
# CT      26.0        8.0   0.249     0.615
# DE       6.0        2.0   0.267     0.667
# NY     124.0       32.0   0.664     0.887
# PA     201.0       51.0   0.279     0.721
# ✅ models/knn_model.pkl
# ✅ models/knn_metrics.json
# === KNN Summary (Stacked Dataset) ===
#
# Dataset: master_stacked.csv (357 rows: flu + COVID + RSV)
# Features: 10 (5 demographic + 2 disease + 3 state)
#
# Best hyperparameters:
#   n_neighbors : 21
#   weights     : distance
#   metric      : manhattan
#
# Headline performance (CV with StratifiedGroupKFold):
#   PR-AUC:   0.470  (random baseline: 0.261)
#   ROC-AUC:  0.659
#   Accuracy: 0.770
#   F1:       0.349
#   Brier:    0.176
#
# Stable features (permutation CI > 0): 9/10
#
# 👉 Next: compare knn_metrics.json vs lr_metrics.json in notebook 08 (comparison).
